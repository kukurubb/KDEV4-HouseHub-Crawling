# %% [markdown]
# ## 형태소 분석

# %%
from glob import glob
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import json

# %%
property_details_dir = "./property_details"
property_detail_paths = glob(os.path.join(property_details_dir, "*.txt"))
print("전체 파일 개수:", len(property_detail_paths))
# Out:
# 전체 파일 개수: 1772

# %% [markdown]
# - 필요한 기능
#     - 딕셔너리 구조를 모르더라도 하나하나 타고 내려가면서 구조별로 파싱하는 기능
#     - 그리고 구조가 다르더라도 충돌이 나지 않고 데이터 집계가 가능해야 함

# %%
def str_to_json(property_detail):
    data_str = ''.join(property_detail) # 문자열 병합
    converted_data = json.loads(data_str) # JSON 파싱

    # 정렬된 JSON 문자열로 변환 (indent=2는 보기 좋게 들여쓰기)
    pretty_json = json.dumps(converted_data, ensure_ascii=False, indent=2)

    return converted_data, pretty_json

# %%
csv_path = "./descriptions.csv"
df = pd.DataFrame(
    columns=["description"],
    data=[],
)

for i, txt_path in enumerate(property_detail_paths):
    with open(txt_path, "r", encoding="utf-8") as f:
        property_detail = f.readlines()
        converted_data, _ = str_to_json(property_detail)
        # csv로 저장을 하기 위해 "," 제거
        data = converted_data["item"]["description"].replace(",", "")
        df.loc[i] = data

    if i == 10:
        break

df.to_csv(csv_path, index=False)

# %%
df
# Out:
#                                           description
# 0   🌷매물 특징🌷\n- 깔끔하고 넓은 쓰리룸+ 입니다. \n- 싱크대 신발장 옵션이 모...
# 1   🏡 건물 정보 🏡\n- 넓은 포룸 구조로 가족 단위 거주에 적합합니다.\n- 깔끔하...
# 2   🏡 건물 정보 🏡\r\n- 넓고 깨끗한 쓰리룸입니다.\r\n- 깔끔한 인테리어와 관...
# 3   🏡 이 집의 특징 🏡\r\n✔️ 넓은 공간의 쓰리룸으로 가족 단위로 살기 좋습니다....
# 4   🏡 이 집의 특징 🏡\r\n✔️ 넓은 공간의 쓰리룸으로 가족 단위로 살기 좋습니다....
# 5   허그보증 전세대출 불가\nHF보증 전세대출 가능\n\n- 임대인이 보증보험 비용 내...
# 6   🏡 이 집의 특징 🏡\r\n✔️ 넓은 공간의 투룸으로 가족 단위로 살기 좋습니다.\...
# 7   🏡 이 집의 특징 🏡\r\n✔️ 넓은 공간의 투룸으로 가족 단위로 살기 좋습니다.\...
# 8   🌟 매물 정보 🌟\r\n- 신축 투룸으로 깔끔하고 깨끗한 인테리어가 특징입니다.\r...
# 9   🌟 매물 특징 🌟\r\n- 신축 건물로 첫 입주 가능한 깨끗한 쓰리룸입니다.\r\n...
# 10  🏡 건물 정보 🏡\n- 주차 가능하며 즉시 입주 가능합니다.\n- 4 5층 2개층을...

# %%
csv_path = "./description_with_corpus.csv"
corpus_df = pd.read_csv(csv_path)

# %%
for i in range(len(corpus_df)):
    print(corpus_df.loc[i, "corpus"])
    print()
# Out:
# "*공부상 면적과 실면적(평수)은 차이가 있을 수 있습니다", "- 깔끔하고 넓은 쓰리룸+ 입니다", "- 넓고 깨끗한 공간에서 편안하게 생활하실 수 있습니다", "- 싱크대 신발장 옵션이 모두 갖춰져 있습니다", "- 주변 환경이 좋아 쾌적하고 편안한 생활을 보장합니다", "- 주변에 다양한 편의시설이 위치해 있어 생활이 편리합니다", "- 주차 가능합니다", "12월", "24년", "26일", "가능합니다", "강조", "갖춰져", "공간에서", "공부상", "깔끔하고", "깨끗한", "넓고", "넓은", "다양한", "매물", "면적과", "모두", "보장합니다", "생활을", "생활이", "생활하실", "수", "신발장", "실면적평수은", "싱크대", "쓰리룸", "여부", "옵션이", "위반건축물", "위반건축물 여부 확인일 : 24년 12월 26일", "위치해", "입니다", "있습니다", "있어", "있을", "좋아", "주변", "주변에", "주차", "차이가", "쾌적하고", "특징", "편리합니다", "편안하게", "편안한", "편의시설이", "확인일", "환경이", "🌷매물 강조🌷", "🌷매물 특징🌷"
#
# "- 깔끔하고 깨끗한 상태로 유지되어 있어 쾌적한 생활 환경을 제공합니다", "- 깔끔하고 깨끗한 인테리어로 바로 입주 가능합니다", "- 넓은 포룸 구조로 가족 단위 거주에 적합합니다", "- 싱크대와 에어컨이 설치되어 있어 생활이 편리합니다", "- 옵션으로 에어컨 김치냉장고 인덕션 냉장고가 포함되어 있습니다", "- 전세 대출 및 보증보험 일부 가능하여 금융 부담을 줄일 수 있습니다", "- 주차 공간이 확보되어 있어 주차 걱정 없습니다", "- 즉시 입주 가능하여 빠른 이사를 원하시는 분들께 최적의 선택입니다", "가능하여", "가능합니다", "가족", "강조", "거주에", "걱정", "건물", "공간이", "구조로", "금융", "김치냉장고", "깔끔하고", "깨끗한", "냉장고가", "넓은", "단위", "대출", "매물", "및", "바로", "보증보험", "부담을", "분들께", "빠른", "사항", "상태로", "생활", "생활이", "선택입니다", "설치되어", "수", "싱크대와", "없습니다", "에어컨", "에어컨이", "옵션으로", "원하시는", "유지되어", "이사를", "인덕션", "인테리어로", "일부", "입주", "있습니다", "있어", "적합합니다", "전세", "정보", "제공합니다", "주차", "줄일", "즉시", "최적의", "추가", "쾌적한", "편리합니다", "포룸", "포함되어", "확보되어", "환경을", "🏡 건물 정보 🏡", "🏡 매물 정보 🏡", "🏡 추가 강조 사항 🏡"
#
# "- 깔끔한 인테리어와 관리가 잘 되어 있습니다", "- 넓고 깨끗한 쓰리룸입니다", "- 주차 공간이 확보되어 있어 주차 걱정 없습니다", "걱정", "건물", "공간이", "관리가", "교통", "깔끔한", "깨끗한", "넓고", "되어", "및", "쓰리룸입니다", "없습니다", "인테리어와", "있습니다", "있어", "잘", "정보", "주차", "확보되어", "🏡 건물 정보 🏡", "🚗 교통 및 주차 🚗"
#
# "✔️ 낮에는 자연광으로 밝고 통풍이 잘됩니다", "✔️ 넓은 공간의 쓰리룸으로 가족 단위로 살기 좋습니다", "✔️ 싱크대 옵션이 구비되어 있습니다", "✔️ 주차 가능합니다", "✔️ 즉시 입주가 가능하여 빠르게 이사를 원하시는 분들에게 좋습니다", "가능하여", "가능합니다", "가족", "공간의", "구비되어", "낮에는", "넓은", "단위로", "밝고", "분들에게", "빠르게", "살기", "싱크대", "쓰리룸으로", "옵션이", "원하시는", "이", "이사를", "입주가", "있습니다", "자연광으로", "잘됩니다", "좋습니다", "주차", "즉시", "집의", "통풍이", "특징", "🏡 이 집의 특징 🏡"
#
# "✔️ 낮에는 자연광으로 밝고 통풍이 잘됩니다", "✔️ 넓은 공간의 쓰리룸으로 가족 단위로 살기 좋습니다", "✔️ 싱크대 옵션이 구비되어 있습니다", "✔️ 주차 가능합니다", "✔️ 즉시 입주가 가능하여 빠르게 이사를 원하시는 분들에게 좋습니다", "가능하여", "가능합니다", "가족", "공간의", "구비되어", "낮에는", "넓은", "단위로", "밝고", "분들에게", "빠르게", "살기", "싱크대", "쓰리룸으로", "옵션이", "원하시는", "이", "이사를", "입주가", "있습니다", "자연광으로", "잘됩니다", "좋습니다", "주차", "즉시", "집의", "통풍이", "특징", "🏡 이 집의 특징 🏡"
#
# "- 건물 내외부에 CCTV가 설치되어 있어 안전하게 생활할 수 있습니다", "- 밝고 유동 인구가 많은 지역으로 여성분들도 안심하고 거주할 수 있습니다", "- 신축급 투룸으로 깔끔하고 깨끗한 상태", "- 애완동물 가능", "- 옵션 : 에어컨 냉장고 세탁기 하이라이트 신발장", "- 임대인이 보증보험 비용 내주신다고 합니다", "- 조용하고 안전한 주택가로 편안한 생활을 누릴 수 있습니다", "- 청량리역에서 도보 7분 거리", "7분", "CCTV가", "HF보증", "HF보증 전세대출 가능", "가능", "거리", "거주할", "건물", "깔끔하고", "깨끗한", "내외부에", "내주신다고", "냉장고", "누릴", "도보", "많은", "밝고", "보증보험", "불가", "비용", "상태", "생활을", "생활할", "설치되어", "세탁기", "수", "신발장", "신축급", "안심하고", "안전하게", "안전한", "애완동물", "에어컨", "여성분들도", "옵션", "유동", "인구가", "임대인이", "있습니다", "있어", "전세대출", "조용하고", "주택가로", "지역으로", "청량리역에서", "투룸으로", "편안한", "하이라이트", "합니다", "허그보증", "허그보증 전세대출 불가"
#
# "✔️ 깔끔하게 관리되어 있어 즉시 입주 가능합니다", "✔️ 넓은 공간의 투룸으로 가족 단위로 살기 좋습니다", "✔️ 싱크대 에어컨 냉장고 세탁기 등의 옵션이 구비되어 있습니다", "✔️ 주차 가능합니다", "가능합니다", "가족", "공간의", "관리되어", "구비되어", "깔끔하게", "냉장고", "넓은", "단위로", "등의", "살기", "세탁기", "싱크대", "에어컨", "옵션이", "이", "입주", "있습니다", "있어", "좋습니다", "주차", "즉시", "집의", "투룸으로", "특징", "🏡 이 집의 특징 🏡"
#
# "✔️ 깔끔하게 관리되어 있어 즉시 입주 가능합니다", "✔️ 넓은 공간의 투룸으로 가족 단위로 살기 좋습니다", "✔️ 싱크대 에어컨 냉장고 세탁기 등의 옵션이 구비되어 있습니다", "✔️ 주차 가능합니다", "가능합니다", "가족", "공간의", "관리되어", "구비되어", "깔끔하게", "냉장고", "넓은", "단위로", "등의", "살기", "세탁기", "싱크대", "에어컨", "옵션이", "이", "입주", "있습니다", "있어", "좋습니다", "주차", "즉시", "집의", "투룸으로", "특징", "🏡 이 집의 특징 🏡"
#
# "- 신축 매물로 깔끔하고 깨끗한 상태를 유지하고 있습니다", "- 신축 투룸으로 깔끔하고 깨끗한 인테리어가 특징입니다", "- 싱크대가 설치되어 있어 주방 활용이 편리합니다", "- 주차 가능하여 차량 소유자에게 최적의 조건을 제공합니다", "- 주차 공간이 마련되어 있어 차량 소유자에게 편리합니다", "- 즉시 입주 가능하며 취득세 전액 지원으로 경제적 혜택을 누릴 수 있습니다", "- 즉시 입주 가능하여 바로 생활 시작할 수 있습니다", "- 취득세 전액 지원으로 경제적 부담을 덜 수 있습니다", "- 투룸 구조로 넓고 쾌적한 생활 공간을 제공합니다", "가능하며", "가능하여", "강조", "경제적", "공간을", "공간이", "구조", "구조로", "깔끔하고", "깨끗한", "넓고", "누릴", "덜", "마련되어", "매물", "매물로", "및", "바로", "부담을", "상태를", "생활", "설치되어", "소유자에게", "수", "시작할", "신축", "싱크대가", "옵션", "유지하고", "인테리어가", "입주", "있습니다", "있어", "전액", "정보", "제공합니다", "조건을", "주방", "주차", "즉시", "지원으로", "차량", "최적의", "취득세", "쾌적한", "투룸", "투룸으로", "특징입니다", "편리합니다", "포인트", "혜택을", "활용이", "🌟 매물 정보 🌟", "🏠 구조 및 옵션 🏠", "💡 강조 포인트 💡"
#
# "- 깔끔하고 깨끗한 내부로 쾌적한 생활을 보장합니다", "- 베란다와 창고가 있어 추가 수납과 공간 활용이 용이합니다", "- 신축 건물로 첫 입주 가능한 깨끗한 쓰리룸입니다", "- 신축 건물로 최신 보안 시스템이 갖춰져 있습니다", "- 안전한 생활을 위한 모든 준비가 완료되어 있습니다", "- 옵션으로 싱크대 신발장 에어컨 2대 하이라이트가 포함되어 있습니다", "- 작은방에는 베란다가 있어 활용도가 높습니다", "- 주차 공간도 마련되어 있어 편리합니다", "- 주차 공간이 마련되어 있어 차량 소유자에게 적합합니다", "- 즉시 입주 가능하여 빠른 이사 가능합니다", "- 현관에는 별도의 창고가 있어 수납공간이 넉넉합니다", "2대", "가능하여", "가능한", "가능합니다", "갖춰져", "건물로", "공간", "공간도", "공간이", "깔끔하고", "깔끔한", "깨끗한", "내부로", "넉넉합니다", "높습니다", "놓치지", "마련되어", "마세요", "매물", "모든", "및", "바로", "베란다가", "베란다와", "별도의", "보안", "보장합니다", "빠른", "생활", "생활을", "소유자에게", "수납공간이", "수납과", "시스템이", "신발장", "신축", "싱크대", "쓰리룸", "쓰리룸입니다", "안전", "안전한", "에어컨", "옵션으로", "완료되어", "용이합니다", "위한", "이사", "입주", "입주의", "있습니다", "있어", "작은방에는", "적합합니다", "주차", "준비가", "즉시", "지금", "지금 바로 입주 가능한 신축 첫 입주의 깔끔한 쓰리룸 놓치지 마세요!", "차량", "창고가", "첫", "최신", "추가", "쾌적한", "특징", "편리합니다", "편의성", "포함되어", "하이라이트가", "현관에는", "활용도가", "활용이", "🌟 매물 특징 🌟", "🌟 보안 및 안전 🌟", "🌟 생활 편의성 🌟"
#
# "- 4 5층 2개층을 함께 사용할 수 있어 공간이 넉넉합니다", "- 넓은 공간을 원하시는 분들에게 최적의 매물입니다", "- 다양한 편의시설이 근처에 있어 생활하기 매우 편리합니다", "- 모아타운 자양2동 C구역에 위치해 있으며 대지지분 약 14평으로 아주 넓습니다", "- 싱크대 옵션이 포함되어 있어 편리하게 사용하실 수 있습니다", "- 옥상 단독 사용이 가능하여 여유로운 생활을 즐기실 수 있습니다", "- 주차 가능하며 즉시 입주 가능합니다", "- 주택가에 위치해 있어 조용하고 쾌적한 생활이 가능합니다", "14평으로", "2개층을", "4", "5층", "C구역에", "가능하며", "가능하여", "가능합니다", "건물", "공간을", "공간이", "근처에", "넉넉합니다", "넓습니다", "넓은", "다양한", "단독", "대지지분", "매물", "매물입니다", "매우", "모아타운", "분들에게", "사용이", "사용하실", "사용할", "생활을", "생활이", "생활하기", "수", "싱크대", "아주", "약", "여유로운", "옥상", "옵션이", "원하시는", "위치해", "입주", "있습니다", "있어", "있으며", "자양2동", "정보", "조용하고", "주변", "주차", "주택가에", "즉시", "즐기실", "최적의", "쾌적한", "특징", "편리하게", "편리합니다", "편의시설이", "포함되어", "함께", "환경", "🏡 건물 정보 🏡", "🏡 매물 특징 🏡", "🏡 주변 환경 🏡"

# %% [markdown]
# ## konply 적용하여 단어 위주로 분석하기

# %%
from konlpy.tag import Okt, Kkma

# %%
from konlpy.tag import Okt, Kkma

okt = Okt()
kkma = Kkma()

text = "주차 가능하고 반려동물도 키울 수 있어요."

print("Okt nouns:", okt.nouns(text))
print("Kkma nouns:", kkma.nouns(text))
# Out:
# Okt nouns: ['주차', '반려동물', '수']
# Kkma nouns: ['주차', '가능', '반려', '반려동물', '동물', '수']

# %%
csv_path = "./descriptions.csv"
df = pd.read_csv(csv_path)

for i in range(len(df)):
    text = df["description"].loc[i]
    
    sentences = kkma.sentences(text)

    for i, sentence in enumerate(sentences):
        print("문장 ---------------------------------------------------------------------")
        print(f"{i+1}. {sentence}")
        print()
        print("단어 ---------------------------------------------------------------------")
        print(kkma.nouns(sentence))
        print("\n\n")

# %%
csv_path = "./descriptions.csv"
df = pd.read_csv(csv_path)

for i in range(len(df)):
    text = df["description"].loc[i]
    
    sentences = kkma.sentences(text)

    for i, sentence in enumerate(sentences):
        print("문장 ---------------------------------------------------------------------")
        print(f"{i+1}. {sentence}")
        print()
        print("단어 ---------------------------------------------------------------------")
        print(okt.nouns(sentence))
        print("\n\n")

    break
# Out:
# 문장 ---------------------------------------------------------------------
# 1. 🌷 매물 특징🌷 - 깔끔하고 넓은 쓰리 룸+ 입니다.
#
# 단어 ---------------------------------------------------------------------
# ['매물', '특징', '룸']
#
#
#
# 문장 ---------------------------------------------------------------------
# 2. - 싱크대 신발장 옵션이 모두 갖춰 져 있습니다.
#
# 단어 ---------------------------------------------------------------------
# ['싱크대', '신발장', '옵션', '모두']
#
#
#
# 문장 ---------------------------------------------------------------------
# 3. - 주차 가능합니다.
#
# 단어 ---------------------------------------------------------------------
# ['주차']
#
#
#
# 문장 ---------------------------------------------------------------------
# 4. - 주변에 다양한 편의 시설이 위치해 있어 생활이 편리합니다.
#
# 단어 ---------------------------------------------------------------------
# ['주변', '편의', '시설', '위치', '생활']
#
#
#
# 문장 ---------------------------------------------------------------------
# 5. 🌷 매물 강조🌷 - 넓고 깨끗한 공간에서 편안하게 생활하실 수 있습니다.
#
# 단어 ---------------------------------------------------------------------
# ['매물', '강조', '공간', '생활', '수']
#
#
#
# 문장 ---------------------------------------------------------------------
# 6. - 주변 환경이 좋아 쾌적하고 편안한 생활을 보장합니다.
#
# 단어 ---------------------------------------------------------------------
# ['주변', '환경', '생활', '보장']
#
#
#
# 문장 ---------------------------------------------------------------------
# 7. * 공부상 면적과 실 면적( 평 수) 은 차이가 있을 수 있습니다.
#
# 단어 ---------------------------------------------------------------------
# ['공부', '면적', '실', '면적', '평', '수', '은', '차이', '수']
#
#
#
# 문장 ---------------------------------------------------------------------
# 8. 위반 건축물 여부 확인 일 : 24년 12월 26일
#
# 단어 ---------------------------------------------------------------------
# ['위반', '건축물', '여부', '확인', '일']

# %%
okt = Okt()
kkma = Kkma()

text = "이 집은 주차가 가능합니다. 반려동물도 키울 수 있어요. 주변에 공원이 많아 좋아요!"
sentences = kkma.sentences(text)

for i, sentence in enumerate(sentences):
    print(f"{i+1}. {sentence}")
# Out:
# 1. 이 집은 주차가 가능합니다.
# 2. 반려 동물도 키울 수 있어요.
# 3. 주변에 공원이 많아 좋아요!

# %%
csv_path = "./descriptions.csv"
df = pd.read_csv(csv_path)

for i in range(len(df)):
    text = df["description"].loc[i]
    
    sentences = kkma.sentences(text)

    for i, sentence in enumerate(sentences):
        print("문장 ---------------------------------------------------------------------")
        print(f"{i+1}. {sentence}")

    break
# Out:
# 문장 ---------------------------------------------------------------------
# 1. 🌷 매물 특징🌷 - 깔끔하고 넓은 쓰리 룸+ 입니다.
# 문장 ---------------------------------------------------------------------
# 2. - 싱크대 신발장 옵션이 모두 갖춰 져 있습니다.
# 문장 ---------------------------------------------------------------------
# 3. - 주차 가능합니다.
# 문장 ---------------------------------------------------------------------
# 4. - 주변에 다양한 편의 시설이 위치해 있어 생활이 편리합니다.
# 문장 ---------------------------------------------------------------------
# 5. 🌷 매물 강조🌷 - 넓고 깨끗한 공간에서 편안하게 생활하실 수 있습니다.
# 문장 ---------------------------------------------------------------------
# 6. - 주변 환경이 좋아 쾌적하고 편안한 생활을 보장합니다.
# 문장 ---------------------------------------------------------------------
# 7. * 공부상 면적과 실 면적( 평 수) 은 차이가 있을 수 있습니다.
# 문장 ---------------------------------------------------------------------
# 8. 위반 건축물 여부 확인 일 : 24년 12월 26일

# %%
df["description"].loc[0]
# Out:
# '🌷매물 특징🌷\n- 깔끔하고 넓은 쓰리룸+ 입니다. \n- 싱크대 신발장 옵션이 모두 갖춰져 있습니다.\n- 주차 가능합니다.\n- 주변에 다양한 편의시설이 위치해 있어 생활이 편리합니다.\n\n🌷매물 강조🌷\n- 넓고 깨끗한 공간에서 편안하게 생활하실 수 있습니다.\n- 주변 환경이 좋아 쾌적하고 편안한 생활을 보장합니다.\n\n*공부상 면적과 실면적(평수)은 차이가 있을 수 있습니다.\n\n위반건축물 여부 확인일 : 24년 12월 26일'
